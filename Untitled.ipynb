# %% [markdown]
# You will be provided with an Excel dataset containing multiple columns. Your focus will be on the "Issue" and "Sub-Issue" columns, which contain textual information describing customer issues and more specific sub-issues. Your goal is to develop an NLP model that can predict the appropriate product category to which each issue belongs.

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("consumer_complaints_copy.csv")

# %%
data
# Out:
#        date_received          product                            sub_product  \
# 0         12-05-2014  Debt collection                               Mortgage
# 1         11-10-2014         Mortgage                         Other mortgage
# 2         08/26/2015         Mortgage                         Other mortgage
# 3         01/16/2014  Debt collection                               Mortgage
# 4         06/25/2015         Mortgage            Conventional fixed mortgage
# ...              ...              ...                                    ...
# 555952    01/26/2014  Debt collection               Non-federal student loan
# 555953    01/26/2016  Debt collection               Non-federal student loan
# 555954    03/31/2016  Debt collection  Other (i.e. phone, health club, etc.)
# 555955    10/13/2015  Debt collection                            Credit card
# 555956    02-03-2014  Debt collection                            Credit card
#
#                                            issue  \
# 0                Disclosure verification of debt
# 1       Loan servicing, payments, escrow account
# 2       Loan modification,collection,foreclosure
# 3                Disclosure verification of debt
# 4       Application, originator, mortgage broker
# ...                                          ...
# 555952       Improper contact or sharing of info
# 555953     Cont'd attempts collect debt not owed
# 555954           Disclosure verification of debt
# 555955           Disclosure verification of debt
# 555956        False statements or representation
#
#                                     sub_issue  \
# 0        Not given enough info to verify debt
# 1                                         NaN
# 2                                         NaN
# 3        Not given enough info to verify debt
# 4                                         NaN
# ...                                       ...
# 555952  Contacted employer after asked not to
# 555953      Debt was discharged in bankruptcy
# 555954   Not given enough info to verify debt
# 555955   Not given enough info to verify debt
# 555956   Impersonated an attorney or official
#
#                              consumer_complaint_narrative  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       My mortgage company has misrepresented themsel...
# ...                                                   ...
# 555952                                                NaN
# 555953                                                NaN
# 555954                                                NaN
# 555955                                                NaN
# 555956                                                NaN
#
#        company_public_response                                   company  \
# 0                          NaN  (Former)Shapiro, Swertfeger & Hasty, LLP
# 1                          NaN  (Former)Shapiro, Swertfeger & Hasty, LLP
# 2                          NaN  (Former)Shapiro, Swertfeger & Hasty, LLP
# 3                          NaN  (Former)Shapiro, Swertfeger & Hasty, LLP
# 4                          NaN      1st 2nd Mortgage Company Of NJ, Inc.
# ...                        ...                                       ...
# 555952                     NaN                      Zwicker & Associates
# 555953                     NaN                      Zwicker & Associates
# 555954                     NaN                      Zwicker & Associates
# 555955                     NaN                      Zwicker & Associates
# 555956                     NaN                      Zwicker & Associates
#
#        state zipcode            tags consumer_consent_provided submitted_via  \
# 0         GA   30005             NaN                       NaN      Referral
# 1         DE   19803             NaN                       NaN      Referral
# 2         GA   30014             NaN                       NaN      Referral
# 3         GA   30087             NaN                       NaN      Referral
# 4         NJ   074XX             NaN          Consent provided           Web
# ...      ...     ...             ...                       ...           ...
# 555952    MN   55428             NaN                       NaN           Web
# 555953    NJ   070XX  Older American          Consent provided           Web
# 555954    FL   33837             NaN                       NaN      Referral
# 555955    FL   33308             NaN                       NaN         Phone
# 555956    TN   38330             NaN                       NaN           Web
#
#        date_sent_to_company     company_response_to_consumer timely_response  \
# 0                12-12-2014                Untimely response              No
# 1                11/19/2014                Untimely response              No
# 2                09-08-2015                Untimely response              No
# 3                02-11-2014                Untimely response              No
# 4                07/22/2015                           Closed             Yes
# ...                     ...                              ...             ...
# 555952           01/27/2014  Closed with non-monetary relief             Yes
# 555953           02-10-2016  Closed with non-monetary relief             Yes
# 555954           04-04-2016          Closed with explanation             Yes
# 555955           10/13/2015  Closed with non-monetary relief             Yes
# 555956           02-03-2014          Closed with explanation             Yes
#
#        consumer_disputed?  complaint_id
# 0                      No       1144671
# 1                      No       1109287
# 2                      No       1536776
# 3                      No        671539
# 4                      No       1437506
# ...                   ...           ...
# 555952                 No        685904
# 555953                 No       1759548
# 555954                 No       1859430
# 555955                 No       1603745
# 555956                 No        698251
#
# [555957 rows x 18 columns]

# %%
df=data[["issue","sub_issue","product"]]

# %%
df
# Out:
#                                            issue  \
# 0                Disclosure verification of debt
# 1       Loan servicing, payments, escrow account
# 2       Loan modification,collection,foreclosure
# 3                Disclosure verification of debt
# 4       Application, originator, mortgage broker
# ...                                          ...
# 555952       Improper contact or sharing of info
# 555953     Cont'd attempts collect debt not owed
# 555954           Disclosure verification of debt
# 555955           Disclosure verification of debt
# 555956        False statements or representation
#
#                                     sub_issue          product
# 0        Not given enough info to verify debt  Debt collection
# 1                                         NaN         Mortgage
# 2                                         NaN         Mortgage
# 3        Not given enough info to verify debt  Debt collection
# 4                                         NaN         Mortgage
# ...                                       ...              ...
# 555952  Contacted employer after asked not to  Debt collection
# 555953      Debt was discharged in bankruptcy  Debt collection
# 555954   Not given enough info to verify debt  Debt collection
# 555955   Not given enough info to verify debt  Debt collection
# 555956   Impersonated an attorney or official  Debt collection
#
# [555957 rows x 3 columns]

# %%
df.shape
# Out:
# (555957, 3)

# %%
df.head(50)
# Out:
#                                        issue  \
# 0            Disclosure verification of debt
# 1   Loan servicing, payments, escrow account
# 2   Loan modification,collection,foreclosure
# 3            Disclosure verification of debt
# 4   Application, originator, mortgage broker
# 5      Cont'd attempts collect debt not owed
# 6   Application, originator, mortgage broker
# 7   Loan servicing, payments, escrow account
# 8   Loan servicing, payments, escrow account
# 9   Loan modification,collection,foreclosure
# 10  Loan modification,collection,foreclosure
# 11  Loan modification,collection,foreclosure
# 12  Loan modification,collection,foreclosure
# 13  Application, originator, mortgage broker
# 14  Application, originator, mortgage broker
# 15  Loan modification,collection,foreclosure
# 16       Improper contact or sharing of info
# 17              Settlement process and costs
# 18       Improper contact or sharing of info
# 19            Credit decision / Underwriting
# 20      Taking/threatening an illegal action
# 21            Credit decision / Underwriting
# 22  Loan servicing, payments, escrow account
# 23  Loan servicing, payments, escrow account
# 24      Taking/threatening an illegal action
# 25       Problems when you are unable to pay
# 26       Improper contact or sharing of info
# 27               Managing the line of credit
# 28                     Communication tactics
# 29       Improper contact or sharing of info
# 30       Improper contact or sharing of info
# 31       Improper contact or sharing of info
# 32        False statements or representation
# 33      Taking/threatening an illegal action
# 34                Managing the loan or lease
# 35      Taking/threatening an illegal action
# 36       Problems when you are unable to pay
# 37       Problems when you are unable to pay
# 38       Problems when you are unable to pay
# 39              Shopping for a loan or lease
# 40                Managing the loan or lease
# 41                Managing the loan or lease
# 42       Problems when you are unable to pay
# 43       Problems when you are unable to pay
# 44       Problems when you are unable to pay
# 45      Taking/threatening an illegal action
# 46                Managing the loan or lease
# 47      Taking/threatening an illegal action
# 48                Managing the loan or lease
# 49       Improper contact or sharing of info
#
#                                 sub_issue          product
# 0    Not given enough info to verify debt  Debt collection
# 1                                     NaN         Mortgage
# 2                                     NaN         Mortgage
# 3    Not given enough info to verify debt  Debt collection
# 4                                     NaN         Mortgage
# 5                        Debt is not mine  Debt collection
# 6                                     NaN         Mortgage
# 7                                     NaN         Mortgage
# 8                                     NaN         Mortgage
# 9                                     NaN         Mortgage
# 10                                    NaN         Mortgage
# 11                                    NaN         Mortgage
# 12                                    NaN         Mortgage
# 13                                    NaN         Mortgage
# 14                                    NaN         Mortgage
# 15                                    NaN         Mortgage
# 16  Talked to a third party about my debt  Debt collection
# 17                                    NaN         Mortgage
# 18  Contacted employer after asked not to  Debt collection
# 19                                    NaN         Mortgage
# 20      Threatened to sue on too old debt  Debt collection
# 21                                    NaN         Mortgage
# 22                                    NaN         Mortgage
# 23                                    NaN         Mortgage
# 24     Seized/Attempted to seize property  Debt collection
# 25                                    NaN    Consumer Loan
# 26  Talked to a third party about my debt  Debt collection
# 27                                    NaN    Consumer Loan
# 28             Frequent or repeated calls  Debt collection
# 29  Contacted employer after asked not to  Debt collection
# 30      Contacted me after I asked not to  Debt collection
# 31      Contacted me after I asked not to  Debt collection
# 32      Attempted to collect wrong amount  Debt collection
# 33      Threatened to sue on too old debt  Debt collection
# 34                                    NaN    Consumer Loan
# 35     Seized/Attempted to seize property  Debt collection
# 36                                    NaN    Consumer Loan
# 37                                    NaN    Consumer Loan
# 38                                    NaN    Consumer Loan
# 39                                    NaN    Consumer Loan
# 40                                    NaN    Consumer Loan
# 41                                    NaN    Consumer Loan
# 42                                    NaN    Consumer Loan
# 43                                    NaN    Consumer Loan
# 44                                    NaN    Consumer Loan
# 45     Seized/Attempted to seize property  Debt collection
# 46                                    NaN    Consumer Loan
# 47   Threatened arrest/jail if do not pay  Debt collection
# 48                                    NaN    Consumer Loan
# 49    Contacted me instead of my attorney  Debt collection

# %%
df.sub_issue.isnull().sum()
# Out:
# 343335

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555957 entries, 0 to 555956
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   issue      555957 non-null  object
#  1   sub_issue  212622 non-null  object
#  2   product    555957 non-null  object
# dtypes: object(3)
# memory usage: 12.7+ MB

# %%
df.isnull().sum()
# Out:
# issue             0
# sub_issue    343335
# product           0
# dtype: int64

# %%
df["product"].value_counts()
# Out:
# Mortgage                   186475
# Debt collection            101052
# Credit reporting            91854
# Credit card                 66468
# Bank account or service     62563
# Consumer Loan               20990
# Student loan                15839
# Payday loan                  3877
# Money transfers              3812
# Prepaid card                 2470
# Other financial service       557
# Name: product, dtype: int64

# %%
len(df["product"].value_counts())
# Out:
# 11

# %%
df.sub_issue.unique()
# Out:
# array(['Not given enough info to verify debt', nan, 'Debt is not mine',
#        'Talked to a third party about my debt',
#        'Contacted employer after asked not to',
#        'Threatened to sue on too old debt',
#        'Seized/Attempted to seize property', 'Frequent or repeated calls',
#        'Contacted me after I asked not to',
#        'Attempted to collect wrong amount',
#        'Threatened arrest/jail if do not pay',
#        'Contacted me instead of my attorney', 'Information is not mine',
#        'Applied for loan/did not receive money', 'Account status',
#        'Threatened to take legal action',
#        'Debt was discharged in bankruptcy', "Can't contact lender",
#        "Can't stop charges to bank account",
#        "Received a loan I didn't apply for",
#        "Charged fees or interest I didn't expect",
#        'Called after sent written cease of comm',
#        'Used obscene/profane/abusive language',
#        'Impersonated an attorney or official',
#        'Indicated committed crime not paying', 'Debt was paid',
#        'Not disclosed as an attempt to collect',
#        'Right to dispute notice not received',
#        'Payment to acct not credited',
#        'Debt resulted from identity theft', 'Account terms',
#        "Sued where didn't live/sign for debt",
#        'Received bad information about my loan',
#        "Don't agree with fees charged",
#        "Indicated shouldn't respond to lawsuit",
#        'Having problems with customer service',
#        'Sued w/o proper notification of suit',
#        'Charged bank acct wrong day or amt', 'Repaying your loan',
#        "Can't get flexible payment options",
#        'Trouble with how payments are handled',
#        'Need information about my balance/terms',
#        "Can't temporarily postpone payments",
#        "Can't decrease my monthly payments",
#        'Qualify for a better loan than offered',
#        'Problems when you are unable to pay', 'Getting a loan',
#        'Keep getting calls about my loan',
#        'Attempted to/Collected exempt funds', 'Called outside of 8am-9pm',
#        'Personal information', 'No notice of investigation status/result',
#        'Public record', 'Problem with statement of dispute',
#        "Can't qualify for a loan", 'Billing dispute',
#        'Reinserted previously deleted info',
#        'Report improperly shared by CRC',
#        'Problem getting report or credit score',
#        'Account terms and changes', 'Inadequate help over the phone',
#        'Problem cancelling or closing account',
#        'Investigation took too long', 'Problem with fraud alerts',
#        'Problem getting my free annual report',
#        'Receiving unwanted marketing/advertising',
#        'Received marketing offer after opted out',
#        'Report shared with employer w/o consent', 'Insurance terms'],
#       dtype=object)

# %%
df.sub_issue.value_counts()
# Out:
# Account status                              26798
# Debt is not mine                            26285
# Information is not mine                     19900
# Not given enough info to verify debt        12496
# Debt was paid                               11328
#                                             ...
# Receiving unwanted marketing/advertising      166
# Report shared with employer w/o consent       127
# Received marketing offer after opted out      125
# Qualify for a better loan than offered        107
# Insurance terms                                 4
# Name: sub_issue, Length: 68, dtype: int64

# %%
len(df.sub_issue.value_counts())
# Out:
# 68

# %%
df.issue.value_counts()
# Out:
# Loan modification,collection,foreclosure    97191
# Incorrect information on credit report      66718
# Loan servicing, payments, escrow account    60375
# Cont'd attempts collect debt not owed       42285
# Account opening, closing, or management     26661
#                                             ...
# Lost or stolen money order                     25
# Incorrect exchange rate                        16
# Lender sold the property                        5
# Lender damaged or destroyed vehicle             5
# Lender damaged or destroyed property            1
# Name: issue, Length: 95, dtype: int64

# %%
len(df.issue.value_counts())
# Out:
# 95

# %%
df["product"].unique()
# Out:
# array(['Debt collection', 'Mortgage', 'Consumer Loan',
#        'Bank account or service', 'Credit reporting', 'Payday loan',
#        'Other financial service', 'Student loan', 'Money transfers',
#        'Prepaid card', 'Credit card'], dtype=object)

# %%
df["sub_issue"]=df["sub_issue"].replace(np.nan," ")
# Out:
# C:\Users\saibo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                                            issue  \
# 0                Disclosure verification of debt
# 1       Loan servicing, payments, escrow account
# 2       Loan modification,collection,foreclosure
# 3                Disclosure verification of debt
# 4       Application, originator, mortgage broker
# ...                                          ...
# 555952       Improper contact or sharing of info
# 555953     Cont'd attempts collect debt not owed
# 555954           Disclosure verification of debt
# 555955           Disclosure verification of debt
# 555956        False statements or representation
#
#                                     sub_issue          product
# 0        Not given enough info to verify debt  Debt collection
# 1                                                     Mortgage
# 2                                                     Mortgage
# 3        Not given enough info to verify debt  Debt collection
# 4                                                     Mortgage
# ...                                       ...              ...
# 555952  Contacted employer after asked not to  Debt collection
# 555953      Debt was discharged in bankruptcy  Debt collection
# 555954   Not given enough info to verify debt  Debt collection
# 555955   Not given enough info to verify debt  Debt collection
# 555956   Impersonated an attorney or official  Debt collection
#
# [555957 rows x 3 columns]

# %%
df["Main_issue"] = df['issue'].astype(str) +" "+ df["sub_issue"]
# Out:
# C:\Users\saibo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                                            issue  \
# 0                Disclosure verification of debt
# 1       Loan servicing, payments, escrow account
# 2       Loan modification,collection,foreclosure
# 3                Disclosure verification of debt
# 4       Application, originator, mortgage broker
# ...                                          ...
# 555952       Improper contact or sharing of info
# 555953     Cont'd attempts collect debt not owed
# 555954           Disclosure verification of debt
# 555955           Disclosure verification of debt
# 555956        False statements or representation
#
#                                     sub_issue          product  \
# 0        Not given enough info to verify debt  Debt collection
# 1                                                     Mortgage
# 2                                                     Mortgage
# 3        Not given enough info to verify debt  Debt collection
# 4                                                     Mortgage
# ...                                       ...              ...
# 555952  Contacted employer after asked not to  Debt collection
# 555953      Debt was discharged in bankruptcy  Debt collection
# 555954   Not given enough info to verify debt  Debt collection
# 555955   Not given enough info to verify debt  Debt collection
# 555956   Impersonated an attorney or official  Debt collection
#
#                                                Main_issue
# 0       Disclosure verification of debt Not given enou...
# 1              Loan servicing, payments, escrow account
# 2              Loan modification,collection,foreclosure
# 3       Disclosure verification of debt Not given enou...
# 4              Application, originator, mortgage broker
# ...                                                   ...
# 555952  Improper contact or sharing of info Contacted ...
# 555953  Cont'd attempts collect debt not owed Debt was...
# 555954  Disclosure verification of debt Not given enou...
# 555955  Disclosure verification of debt Not given enou...
# 555956  False statements or representation Impersonate...
#
# [555957 rows x 4 columns]

# %%
df1=df[["Main_issue","product"]]

# %%
df1
# Out:
#                                                Main_issue          product
# 0       Disclosure verification of debt Not given enou...  Debt collection
# 1              Loan servicing, payments, escrow account           Mortgage
# 2              Loan modification,collection,foreclosure           Mortgage
# 3       Disclosure verification of debt Not given enou...  Debt collection
# 4              Application, originator, mortgage broker           Mortgage
# ...                                                   ...              ...
# 555952  Improper contact or sharing of info Contacted ...  Debt collection
# 555953  Cont'd attempts collect debt not owed Debt was...  Debt collection
# 555954  Disclosure verification of debt Not given enou...  Debt collection
# 555955  Disclosure verification of debt Not given enou...  Debt collection
# 555956  False statements or representation Impersonate...  Debt collection
#
# [555957 rows x 2 columns]

# %%
# for importing label encoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
# for applying label encoder
df1['product'] = le.fit_transform(df['product'])
# Out:
# C:\Users\saibo\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1
# Out:
#                                                Main_issue  product
# 0       Disclosure verification of debt Not given enou...        4
# 1              Loan servicing, payments, escrow account          6
# 2              Loan modification,collection,foreclosure          6
# 3       Disclosure verification of debt Not given enou...        4
# 4              Application, originator, mortgage broker          6
# ...                                                   ...      ...
# 555952  Improper contact or sharing of info Contacted ...        4
# 555953  Cont'd attempts collect debt not owed Debt was...        4
# 555954  Disclosure verification of debt Not given enou...        4
# 555955  Disclosure verification of debt Not given enou...        4
# 555956  False statements or representation Impersonate...        4
#
# [555957 rows x 2 columns]

# %%
# X for input y for output/ prediction
X = df1['Main_issue']
y = df1['product']

# %%
X
# Out:
# 0         Disclosure verification of debt Not given enou...
# 1                Loan servicing, payments, escrow account
# 2                Loan modification,collection,foreclosure
# 3         Disclosure verification of debt Not given enou...
# 4                Application, originator, mortgage broker
#                                 ...
# 555952    Improper contact or sharing of info Contacted ...
# 555953    Cont'd attempts collect debt not owed Debt was...
# 555954    Disclosure verification of debt Not given enou...
# 555955    Disclosure verification of debt Not given enou...
# 555956    False statements or representation Impersonate...
# Name: Main_issue, Length: 555957, dtype: object

# %%
y
# Out:
# 0         4
# 1         6
# 2         6
# 3         4
# 4         6
#          ..
# 555952    4
# 555953    4
# 555954    4
# 555955    4
# 555956    4
# Name: product, Length: 555957, dtype: int32

# %%
# for stlyling only
from tqdm import tqdm
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import re

# %%
ps = PorterStemmer()
corpus = []

for i in tqdm(range(len(X))):
#     print(i, end=', ')
    review = re.sub("[^a-zA-Z]"," ",X[i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if word not in set(stopwords.words("english"))]
    review = " ".join(review)
    corpus.append(review)
# Out:
#   1%|▋                                                                          | 5149/555957 [00:13<21:42, 422.93it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-45a635dc2dbd> in <module>
#       7     review = review.lower()
#       8     review = review.split()
# ----> 9     review = [ps.stem(word) for word in review if word not in set(stopwords.words("english"))]
#      10     review = " ".join(review)
#      11     corpus.append(review)
#
# <ipython-input-36-45a635dc2dbd> in <listcomp>(.0)
#       7     review = review.lower()
#       8     review = review.split()
# ----> 9     review = [ps.stem(word) for word in review if word not in set(stopwords.words("english"))]
#      10     review = " ".join(review)
#      11     corpus.append(review)
#
# ~\anaconda3\lib\site-packages\nltk\corpus\reader\wordlist.py in words(self, fileids, ignore_lines_startswith)
#      23         return [
#      24             line
# ---> 25             for line in line_tokenize(self.raw(fileids))
#      26             if not line.startswith(ignore_lines_startswith)
#      27         ]
#
# ~\anaconda3\lib\site-packages\nltk\corpus\reader\wordlist.py in raw(self, fileids)
#      32         elif isinstance(fileids, string_types):
#      33             fileids = [fileids]
# ---> 34         return concat([self.open(f).read() for f in fileids])
#      35
#      36
#
# ~\anaconda3\lib\site-packages\nltk\corpus\reader\wordlist.py in <listcomp>(.0)
#      32         elif isinstance(fileids, string_types):
#      33             fileids = [fileids]
# ---> 34         return concat([self.open(f).read() for f in fileids])
#      35
#      36
#
# ~\anaconda3\lib\site-packages\nltk\corpus\reader\api.py in open(self, file)
#     211         """
#     212         encoding = self.encoding(file)
# --> 213         stream = self._root.join(file).open(encoding)
#     214         return stream
#     215
#
# ~\anaconda3\lib\site-packages\nltk\data.py in join(self, fileid)
#     353     def join(self, fileid):
#     354         _path = os.path.join(self._path, fileid)
# --> 355         return FileSystemPathPointer(_path)
#     356
#     357     def __repr__(self):
#
# ~\anaconda3\lib\site-packages\nltk\compat.py in _decorator(*args, **kwargs)
#     226     def _decorator(*args, **kwargs):
#     227         args = (args[0], add_py3_data(args[1])) + args[2:]
# --> 228         return init_func(*args, **kwargs)
#     229
#     230     return wraps(init_func)(_decorator)
#
# ~\anaconda3\lib\site-packages\nltk\data.py in __init__(self, _path)
#     330
#     331         _path = os.path.abspath(_path)
# --> 332         if not os.path.exists(_path):
#     333             raise IOError('No such file or directory: %r' % _path)
#     334         self._path = _path
#
# ~\anaconda3\lib\genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except OSError:
#      21         return False
#
# KeyboardInterrupt:
